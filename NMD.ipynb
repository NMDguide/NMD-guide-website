# %%
# !pip install -U scikit-learn
# Out:
# ...
#      ---------------------------------------- 8.4/8.4 MB 381.1 kB/s eta 0:00:00
# ...
#      ------------------------------------ 298.0/298.0 kB 428.2 kB/s eta 0:00:00
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ...

# %%
# !pip install GEOparse
# Out:
# ...
#      ------------------------------------ 278.5/278.5 kB 464.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for GEOparse: filename=GEOparse-2.0.3-py3-none-any.whl size=29065 sha256=c528a1c57507fcc818dcffccb4d14a413f8057b62290bbfe628f2b653efdd8a8
#   Stored in directory: c:\users\marye\appdata\local\pip\cache\wheels\b4\27\3b\3faf8423d9c4fad02d693b4d75d1b6e82fde1d5cf59cc9a40e
# Successfully built GEOparse
# ...

# %%
import numpy as np 
import pandas as pd
dataset = pd.read_csv("dataIWithTargetValues-txt.csv")
#dataset2 = pd.read_csv("dataII.csv")

# %%
df
# Out:
#              "GSM74239"        "GSM74240"        "GSM74241"        "GSM74242"  \
# 1      53.7452507019043  398.217529296875  476.876739501953  285.281463623047
# 2      483.366943359375   318.69580078125  233.067993164062  377.694519042969
# 3      3044.49267578125  3614.12182617188  2816.37841796875  2772.38403320312
# 4      207.656005859375  152.559188842773   99.692138671875  133.170013427734
# 5       1056.7705078125  865.037780761719  653.934692382812  675.938415527344
# ...                 ...               ...               ...               ...
# 22279  109.582931518555  147.647933959961  33.9032745361328  79.7916870117188
# 22280   32.877571105957  14.4215307235718  6.36603403091431  47.8829078674316
# 22281  34.0942687988281  32.8462257385254  29.4277782440186   19.107120513916
# 22282  35.3568077087402  22.4525661468506  10.9492521286011  10.4670381546021
# 22283               BMD               ALS               ALS               ALS
#
# ...

# %%
for i in range(0,22284):
    for j in range(0,122):
        s=dataset.iloc[i,j]
        
        dataset.iloc[i,j]=s[1:-1]

# %%
df=dataset.T

# %%
dfX
# Out:
#                         0                 1                 2      \
# "GSM74239"   1565.09008789062  53.7452507019043  483.366943359375
# "GSM74240"   1793.82397460938  398.217529296875   318.69580078125
# "GSM74241"   2058.33154296875  476.876739501953  233.067993164062
# "GSM74242"     2189.998046875  285.281463623047  377.694519042969
# "GSM74243"   1900.70324707031  418.731475830078  336.891204833984
# ...                       ...               ...               ...
# "GSM121396"  1693.46533203125  400.810791015625  356.851776123047
# "GSM121397"    2706.814453125  236.318222045898  272.176849365234
# "GSM121398"  1790.87670898438  210.678695678711  219.225784301758
# "GSM121399"  1854.69946289062  176.634094238281  224.363571166992
# "GSM121407"  2254.56396484375   159.44287109375  435.373107910156
#
#                         3                 4                 5      \
# "GSM74239"   3044.49267578125  207.656005859375   1056.7705078125
# ...

# %%
dfX=df.iloc[1:,:]

# %%
dfX.iloc[1:,:]
# Out:
#                         0                 1                 2      \
# "GSM74240"   1793.82397460938  398.217529296875   318.69580078125
# "GSM74241"   2058.33154296875  476.876739501953  233.067993164062
# "GSM74242"     2189.998046875  285.281463623047  377.694519042969
# "GSM74243"   1900.70324707031  418.731475830078  336.891204833984
# "GSM74244"   1986.62121582031  308.545440673828  305.663177490234
# ...                       ...               ...               ...
# "GSM121396"  1693.46533203125  400.810791015625  356.851776123047
# "GSM121397"    2706.814453125  236.318222045898  272.176849365234
# "GSM121398"  1790.87670898438  210.678695678711  219.225784301758
# "GSM121399"  1854.69946289062  176.634094238281  224.363571166992
# "GSM121407"  2254.56396484375   159.44287109375  435.373107910156
#
#                         3                 4                 5      \
# "GSM74240"   3614.12182617188  152.559188842773  865.037780761719
# ...

# %%
from sklearn.model_selection import train_test_split
training_set, test_set = train_test_split(dfX, test_size = 0.2, random_state = 1)

# %%
X_train = training_set.iloc[:,0:22282].values
Y_train = training_set.iloc[:,22283].values
X_test = test_set.iloc[:,0:22282].values
Y_test = test_set.iloc[:,22283].values

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='rbf', random_state = 1)
classifier.fit(X_train,Y_train)
# Out:
# SVC(random_state=1)

# %%
Y_pred = classifier.predict(X_test)

# %%
test_set["Predictions"] = Y_pred

# %%
test_set
# Out:
#                             0                 1                 2  \
# "GSM121372"  1984.01306152344  202.490051269531   279.75048828125
# "GSM74395"   2366.96655273438  305.328002929688  657.839416503906
# "GSM74400"   2049.08325195312  298.284240722656    442.2568359375
# "GSM121398"  1790.87670898438  210.678695678711  219.225784301758
# "GSM74418"   2164.83544921875  57.8686370849609  473.548217773438
# "GSM74387"   2287.66552734375  337.606231689453  269.252166748047
# "GSM74372"   2048.94384765625  303.778198242188   632.32861328125
# "GSM121358"  1646.81079101562  295.649291992188  435.100067138672
# "GSM74389"   2568.73803710938  269.596466064453  350.002807617188
# "GSM121379"  1780.72619628906  324.067840576172  279.161254882812
# "GSM121374"  1593.49829101562  209.768035888672    414.5478515625
# "GSM121380"     2004.44140625  323.534271240234  306.088348388672
# "GSM74241"   2058.33154296875  476.876739501953  233.067993164062
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,Y_pred)
accuracy = float(cm.diagonal().sum())/len(Y_test)
print("\nAccuracy Of SVM For The Given Dataset : ", accuracy)
# Out:
# Accuracy Of SVM For The Given Dataset :  0.68
